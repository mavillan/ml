# %% [markdown]
# # Tarea N°3 - Máquinas de Aprendizaje - ILI393
# ### Martín Villanueva A.

# %% [markdown]
# ## Introducción

# %% [markdown]
# En la presente tarea, se experimenta con algoritmos relacionados con redes neuronales artificiales, y ensamblado de máquinas con árboles de clasificación. La mayor parte de los algoritmos probados, corresponden a las implementaciones de Scikit-Learn, excepto por Extreme Learning Machines y Bagging que fueron implementadas, de modo que son compatibles con dicha libreria.
#
# Donde corresponda, se realiza stratified 5-fold cross validation para la selección de los parámetros óptimos. Por temas de espacio, sólo se muestran los resultados de tal proceso en 2 datasets de los 20. Se muestra también histogramas de los mejores parámetros sobre los 20 datasets.
#
# Para la comparación de los errores, se realizan error bars con el promedio del error sobre los 20 datasets. Las barras de error son computadas con el intervalo de confianza para la t-student (del error-rate medio) del 90%.

# %% [markdown]
# ## 1. Feedforward ANN sin weight decay

# %%
#parameters to try on MPL
mlp_params = {'hidden_layer_sizes':[(25,),(50,),(75,),(100,),(125)], 'learning_rate_init':[0.05, 0.075, 0.1, 0.125, 0.15]}

# %%
mlp = MLPClassifier(activation='logistic', algorithm='sgd', learning_rate='constant', alpha=0.)
mlp_tr_err, mlp_ts_err = solve_clf(mlp, params=mlp_params, show=[3,17])
# Out:
# ##############################################################
# Dataset: 3
# Best parameter: {'learning_rate_init': 0.1, 'hidden_layer_sizes': (75,)}
# CV scores:
# mean: 0.77257, std: 0.02643, params: {'learning_rate_init': 0.05, 'hidden_layer_sizes': (25,)}
# mean: 0.78125, std: 0.02706, params: {'learning_rate_init': 0.075, 'hidden_layer_sizes': (25,)}
# mean: 0.77604, std: 0.02393, params: {'learning_rate_init': 0.1, 'hidden_layer_sizes': (25,)}
# mean: 0.77083, std: 0.02553, params: {'learning_rate_init': 0.125, 'hidden_layer_sizes': (25,)}
# mean: 0.77257, std: 0.03016, params: {'learning_rate_init': 0.15, 'hidden_layer_sizes': (25,)}
# mean: 0.78299, std: 0.02172, params: {'learning_rate_init': 0.05, 'hidden_layer_sizes': (50,)}
# mean: 0.76910, std: 0.03072, params: {'learning_rate_init': 0.075, 'hidden_layer_sizes': (50,)}
# mean: 0.77951, std: 0.01755, params: {'learning_rate_init': 0.1, 'hidden_layer_sizes': (50,)}
# mean: 0.77257, std: 0.03277, params: {'learning_rate_init': 0.125, 'hidden_layer_sizes': (50,)}
# mean: 0.77951, std: 0.01681, params: {'learning_rate_init': 0.15, 'hidden_layer_sizes': (50,)}
# mean: 0.77778, std: 0.01983, params: {'learning_rate_init': 0.05, 'hidden_layer_sizes': (75,)}
# mean: 0.77257, std: 0.02242, params: {'learning_rate_init': 0.075, 'hidden_layer_sizes': (75,)}
# mean: 0.78993, std: 0.01636, params: {'learning_rate_init': 0.1, 'hidden_layer_sizes': (75,)}
# mean: 0.77604, std: 0.01796, params: {'learning_rate_init': 0.125, 'hidden_layer_sizes': (75,)}
# mean: 0.78472, std: 0.01964, params: {'learning_rate_init': 0.15, 'hidden_layer_sizes': (75,)}
# mean: 0.77431, std: 0.02264, params: {'learning_rate_init': 0.05, 'hidden_layer_sizes': (100,)}
# mean: 0.76910, std: 0.03195, params: {'learning_rate_init': 0.075, 'hidden_layer_sizes': (100,)}
# mean: 0.76910, std: 0.02849, params: {'learning_rate_init': 0.1, 'hidden_layer_sizes': (100,)}
# mean: 0.77778, std: 0.00886, params: {'learning_rate_init': 0.125, 'hidden_layer_sizes': (100,)}
# mean: 0.76910, std: 0.04243, params: {'learning_rate_init': 0.15, 'hidden_layer_sizes': (100,)}
# mean: 0.76389, std: 0.02521, params: {'learning_rate_init': 0.05, 'hidden_layer_sizes': 125}
# mean: 0.78299, std: 0.02210, params: {'learning_rate_init': 0.075, 'hidden_layer_sizes': 125}
# mean: 0.77431, std: 0.01975, params: {'learning_rate_init': 0.1, 'hidden_layer_sizes': 125}
# mean: 0.76215, std: 0.01838, params: {'learning_rate_init': 0.125, 'hidden_layer_sizes': 125}
# mean: 0.77257, std: 0.03031, params: {'learning_rate_init': 0.15, 'hidden_layer_sizes': 125}
# Training error: 0.213541666667
# Testing error: 0.25
# ##############################################################
#
#
# ##############################################################
# Dataset: 17
# Best parameter: {'learning_rate_init': 0.1, 'hidden_layer_sizes': (100,)}
# CV scores:
# mean: 0.77257, std: 0.02725, params: {'learning_rate_init': 0.05, 'hidden_layer_sizes': (25,)}
# mean: 0.77431, std: 0.01932, params: {'learning_rate_init': 0.075, 'hidden_layer_sizes': (25,)}
# mean: 0.76910, std: 0.01807, params: {'learning_rate_init': 0.1, 'hidden_layer_sizes': (25,)}
# mean: 0.78472, std: 0.01765, params: {'learning_rate_init': 0.125, 'hidden_layer_sizes': (25,)}
# mean: 0.77778, std: 0.01671, params: {'learning_rate_init': 0.15, 'hidden_layer_sizes': (25,)}
# mean: 0.77951, std: 0.01590, params: {'learning_rate_init': 0.05, 'hidden_layer_sizes': (50,)}
# mean: 0.77083, std: 0.01335, params: {'learning_rate_init': 0.075, 'hidden_layer_sizes': (50,)}
# mean: 0.77604, std: 0.02108, params: {'learning_rate_init': 0.1, 'hidden_layer_sizes': (50,)}
# mean: 0.77431, std: 0.01839, params: {'learning_rate_init': 0.125, 'hidden_layer_sizes': (50,)}
# mean: 0.77604, std: 0.01483, params: {'learning_rate_init': 0.15, 'hidden_layer_sizes': (50,)}
# mean: 0.77431, std: 0.02273, params: {'learning_rate_init': 0.05, 'hidden_layer_sizes': (75,)}
# mean: 0.77604, std: 0.01899, params: {'learning_rate_init': 0.075, 'hidden_layer_sizes': (75,)}
# mean: 0.78125, std: 0.01647, params: {'learning_rate_init': 0.1, 'hidden_layer_sizes': (75,)}
# mean: 0.78299, std: 0.02750, params: {'learning_rate_init': 0.125, 'hidden_layer_sizes': (75,)}
# mean: 0.78819, std: 0.01484, params: {'learning_rate_init': 0.15, 'hidden_layer_sizes': (75,)}
# mean: 0.76910, std: 0.02436, params: {'learning_rate_init': 0.05, 'hidden_layer_sizes': (100,)}
# mean: 0.78125, std: 0.02355, params: {'learning_rate_init': 0.075, 'hidden_layer_sizes': (100,)}
# mean: 0.78993, std: 0.01889, params: {'learning_rate_init': 0.1, 'hidden_layer_sizes': (100,)}
# mean: 0.77604, std: 0.00903, params: {'learning_rate_init': 0.125, 'hidden_layer_sizes': (100,)}
# mean: 0.78125, std: 0.01952, params: {'learning_rate_init': 0.15, 'hidden_layer_sizes': (100,)}
# mean: 0.77778, std: 0.01941, params: {'learning_rate_init': 0.05, 'hidden_layer_sizes': 125}
# mean: 0.77951, std: 0.02539, params: {'learning_rate_init': 0.075, 'hidden_layer_sizes': 125}
# mean: 0.77778, std: 0.02537, params: {'learning_rate_init': 0.1, 'hidden_layer_sizes': 125}
# mean: 0.76910, std: 0.01515, params: {'learning_rate_init': 0.125, 'hidden_layer_sizes': 125}
# mean: 0.77951, std: 0.00867, params: {'learning_rate_init': 0.15, 'hidden_layer_sizes': 125}
# Training error: 0.204861111111
# Testing error: 0.276041666667
# ##############################################################

# %% [markdown]
# ## 2. Feedforward ANN con weight decay

# %%
#parameters to try on MPL
mlp_params = {'alpha':[0.005, 0.01, 0.05, 0.1, 0.5]}

# %%
mlp = MLPClassifier(activation='logistic', algorithm='sgd', learning_rate='constant', learning_rate_init=0.15, hidden_layer_sizes=(100,))
mlp_tr_err, mlp_ts_err = solve_clf(mlp, params=mlp_params, show=[3,17])
# Out:
# ##############################################################
# Dataset: 3
# Best parameter: {'alpha': 0.5}
# CV scores:
# mean: 0.76215, std: 0.04417, params: {'alpha': 0.005}
# mean: 0.76215, std: 0.02380, params: {'alpha': 0.01}
# mean: 0.76389, std: 0.02961, params: {'alpha': 0.05}
# mean: 0.73611, std: 0.04970, params: {'alpha': 0.1}
# mean: 0.76736, std: 0.02277, params: {'alpha': 0.5}
# Training error: 0.211805555556
# Testing error: 0.244791666667
# ##############################################################
#
#
# ##############################################################
# Dataset: 17
# Best parameter: {'alpha': 0.5}
# CV scores:
# mean: 0.77257, std: 0.01575, params: {'alpha': 0.005}
# mean: 0.77257, std: 0.02696, params: {'alpha': 0.01}
# mean: 0.76736, std: 0.00832, params: {'alpha': 0.05}
# mean: 0.77257, std: 0.01388, params: {'alpha': 0.1}
# mean: 0.77604, std: 0.02693, params: {'alpha': 0.5}
# Training error: 0.206597222222
# Testing error: 0.291666666667
# ##############################################################

# %% [markdown]
# ## 3. Extreme Learning Machine

# %%
elm_params = {'n_hidden':[50,100,150,200,250]}

# %%
elm = ELM()
elm_tr_err, elm_ts_err = solve_clf(elm, params=elm_params, show=[3,17])
# Out:
# ##############################################################
# Dataset: 3
# Best parameter: {'n_hidden': 100}
# CV scores:
# mean: 0.77431, std: 0.02100, params: {'n_hidden': 50}
# mean: 0.77951, std: 0.02435, params: {'n_hidden': 100}
# mean: 0.77951, std: 0.02435, params: {'n_hidden': 150}
# mean: 0.77083, std: 0.02214, params: {'n_hidden': 200}
# mean: 0.77431, std: 0.02547, params: {'n_hidden': 250}
# Training error: 0.210069444444
# Testing error: 0.223958333333
# ##############################################################
#
#
# ##############################################################
# Dataset: 17
# Best parameter: {'n_hidden': 150}
# CV scores:
# mean: 0.77778, std: 0.02317, params: {'n_hidden': 50}
# mean: 0.77431, std: 0.01670, params: {'n_hidden': 100}
# mean: 0.78125, std: 0.01218, params: {'n_hidden': 150}
# mean: 0.77604, std: 0.01632, params: {'n_hidden': 200}
# mean: 0.77951, std: 0.01444, params: {'n_hidden': 250}
# Training error: 0.199652777778
# Testing error: 0.270833333333
# ##############################################################

# %% [markdown]
# ## 4. AdaBoost

# %%
clf = AdaBoost(base_estimator=DecisionTree(max_depth=1), n_estimators=5)
ada_5_tr_err, ada_5_ts_err = solve_clf(clf, scale=False, show=[])

# %%
clf = AdaBoost(base_estimator=DecisionTree(max_depth=1), n_estimators=10)
ada_10_tr_err, ada_10_ts_err = solve_clf(clf, scale=False, show=[])

# %%
clf = AdaBoost(base_estimator=DecisionTree(max_depth=1), n_estimators=15)
ada_15_tr_err, ada_15_ts_err = solve_clf(clf, scale=False, show=[])

# %%
clf = AdaBoost(base_estimator=DecisionTree(max_depth=1), n_estimators=20)
ada_20_tr_err, ada_20_ts_err = solve_clf(clf, scale=False, show=[])

# %%
tr_errors = [('Adaboost 5',ada_5_tr_err), ('Adaboost 10',ada_10_tr_err), ('Adaboost 15',ada_15_tr_err), ('Adaboost 20',ada_20_tr_err)]
plot_errorbars(tr_errors, title='Training error comparison on Adaboost: max_depth=1 and varying n_estimator')

# %%
ts_errors = [('Adaboost 5',ada_5_ts_err), ('Adaboost 10',ada_10_ts_err), ('Adaboost 15',ada_15_ts_err), ('Adaboost 20',ada_20_ts_err)]
plot_errorbars(ts_errors, title='Testing error comparison on Adaboost: max_depth=1 and varying n_estimator')

# %% [markdown]
# ## 5. Bagging

# %%
clf = Bagging(n_estimators=5, max_depth=1)
bag_5_tr_err, bag_5_ts_err = solve_clf(clf, scale=False, show=[])

# %%
clf = Bagging(n_estimators=10, max_depth=1)
bag_10_tr_err, bag_10_ts_err = solve_clf(clf, scale=False, show=[])

# %%
clf = Bagging(n_estimators=15, max_depth=1)
bag_15_tr_err, bag_15_ts_err = solve_clf(clf, scale=False, show=[])

# %%
clf = Bagging(n_estimators=20, max_depth=1)
bag_20_tr_err, bag_20_ts_err = solve_clf(clf, scale=False, show=[])

# %%
tr_errors = [('Bagging 5',bag_5_tr_err), ('Bagging 10',bag_10_tr_err), ('Bagging 15',bag_15_tr_err), ('Bagging 20',bag_20_tr_err)]
plot_errorbars(tr_errors, title='Training error comparison on Bagging: max_depth=1 and varying n_estimator')

# %%
ts_errors = [('Bagging 5',bag_5_ts_err), ('Bagging 10',bag_10_ts_err), ('Bagging 15',bag_15_ts_err), ('Bagging 20',bag_20_ts_err)]
plot_errorbars(ts_errors, title='Testing error comparison on Bagging: max_depth=1 and varying n_estimator')

# %% [markdown]
# ## 6. Variando la profundidad de los árboles

# %% [markdown]
# ## 7. Comparaciones

# %%
errors = [('AdaBoost',adaboost_ts_err), ('Bagging',bagging_ts_err), ('ELM',elm_ts_err)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-86-a9f2b85d58d1> in <module>()
# ----> 1 errors = [('AdaBoost',adaboost_ts_err), ('Bagging',bagging_ts_err), ('ELM',elm_ts_err)]
#
# NameError: name 'adaboost_ts_err' is not defined

# %%
plot_errorbars(errors)

# %% [markdown]
# ## Anexo de Código

# %% [markdown]
# **Observación:** Para la correcta ejecución del código en el informe, primero se deben ejecutar las celdas del anexo de código aquí abajo.

# %% [markdown]
# ### Configuración del notebook

# %%
#notebook settings
# %matplotlib inline

#import some useful libraries and utilities
import numpy as np
import scipy as sp
import matplotlib.cm as cm
import matplotlib.pyplot as plt
from sklearn.grid_search import GridSearchCV
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.utils import resample
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier as DecisionTree
from sklearn.ensemble import AdaBoostClassifier as AdaBoost

# %% [markdown]
# ### Configuración del notebook

# %% [markdown]
# ## Métricas de error para clasificación

# %%
#precision
def precision(yreal, ypred):
    yr = yreal.astype(int)
    yp = ypred.astype(int) 
    m, = yr.shape
    #number of good predictions/number of predictions
    return np.sum(yp==yr)/float(m)

#error rate 
def error_rate(yreal, ypred):
    return 1.-precision(yreal, ypred)

# %% [markdown]
# ## Funciones complementarias (helpers) para obtener resultados

# %%
"""
Function to generate histogram of winners
"""
def make_hist(winners,params):
    for key in winners:
        par = params[key]
        win = np.array(winners[key])
        freqs = np.zeros(5)
        for i in xrange(5):
            freqs[i] = np.sum(par[i]==win)
        labels = map(str,par)
        pos = np.arange(len(labels))
        width = 1.0
        fig = plt.figure()
        fig.set_figheight(6)
        fig.set_figwidth(6)
        ax = plt.axes()
        ax.set_xticks(pos + (width / 2))
        ax.set_xticklabels(labels)
        plt.xlabel('Parameters')
        plt.ylabel('Frequency')
        plt.title('Histogram of {0}'.format(key))
        plt.bar(pos, freqs, width, color='0.5')
        plt.show()
    
def plot_error(tr_err, ts_err):
    x = np.arange(20)
    plt.figure(figsize=(12,6))
    plt.plot(x, tr_err, marker='o', linestyle='--', color='b', label='Training Error')
    plt.plot(x, ts_err, marker='o', linestyle='--', color='r', label='Testing Error')
    plt.xlabel('Datasets')
    plt.ylabel('Error Rate')
    plt.title('Training and testing error rates in each dataset')
    plt.legend(bbox_to_anchor=(1.25, 1.0))
    plt.show()
    

def mean_confidence_interval(data, confidence=0.9):
    #computing confidence interval
    n = data.shape[0]
    mu = np.mean(data)
    sem = sp.stats.sem(data)
    h1,h2 = sp.stats.t.interval(confidence, n-1, loc=mu, scale=sem)
    return mu, h1, h2

def mean_percentile(data, inf=10, sup=90):
    mu = np.mean(data)
    h1, h2 = np.percentile(data, [10,90])
    return mu, h1, h2

def plot_errorbars(errors, title=None):
    mean = []
    lower = []
    upper = []
    labels = []
    for label,error in errors:
        mu,l,u = mean_confidence_interval(error)
        #mu,l,u = mean_percentile(error)
        mean.append(mu)
        lower.append(l)
        upper.append(u)
        labels.append(label)
    x = np.arange(3, len(errors)+3)
    mean = np.array(mean)
    lower = mean-np.array(lower)
    upper = np.array(upper)-mean
    plt.figure(figsize=(12,6))
    plt.xlim([2,len(errors)+3])
    plt.xticks(x, labels)
    plt.errorbar(x, mean, yerr=[lower,upper],fmt='o')
    plt.xlabel('Algorithm')
    plt.ylabel('Mean error rate')
    plt.title(title)
    plt.show()

"""
Generate solutions for classification problems
"""
def solve_clf(clf, params=None, scale=True, show=None):
    if params is not None:
        winners = dict()
        for key in params:
            winners[key] = list()
            
    #set dataset name
    path = './diabetes/diabetes'
    
    #error-rates to plot
    tr_err = np.empty(20)
    ts_err = np.empty(20)
    
    #iterate through data
    for i in xrange(20):
        #loading datasets
        tr_file = path+'-tr-{0}.npy'.format(i)
        ts_file = path+'-ts-{0}.npy'.format(i)
            
        tr_data = np.load(tr_file)
        ts_data = np.load(ts_file)
        
        if scale:
            #perform same scaling on training and testing sets
            scaler = StandardScaler()
            scaler.fit(tr_data[:,:-1])
            X_tr = scaler.transform(tr_data[:,:-1])
            X_ts = scaler.transform(ts_data[:,:-1])
        else: 
            X_tr = tr_data[:,:-1]
            X_ts = ts_data[:,:-1]
        y_tr = np.ascontiguousarray(tr_data[:,-1])
        y_ts = np.ascontiguousarray(ts_data[:,-1])

        if params is not None:
            #tunning parameters
            gs = GridSearchCV(clf, params, cv=5, n_jobs=2)
            gs.fit(X_tr, y_tr)
            grid_scores = gs.grid_scores_
            best_params = gs.best_params_
            for key in winners:
                bparam = best_params[key]
                if type(bparam)==tuple:
                    winners[key].append(bparam[0])
                else:
                    winners[key].append(bparam)
            #traininig with best parameters
            clf.set_params(**best_params)
            clf.fit(X_tr, y_tr)
        else:
            clf.fit(X_tr, y_tr)
        
        #computing errors
        tr_err[i] = error_rate(y_tr, clf.predict(X_tr))
        ts_err[i] = error_rate(y_ts, clf.predict(X_ts))
        
        if (show != None) and (i not in show): continue
        print "##############################################################"
        print "Dataset: {0}".format(i)
        if params is not None:
            print 'Best parameter: {0}'.format(best_params)
            print 'CV scores:'
            for result in grid_scores: print result
        print 'Training error: {0}'.format(tr_err[i])
        print 'Testing error: {0}'.format(ts_err[i])
        print "##############################################################"
        print '\n'
    
    #ploting errors
    if show: 
        plot_error(tr_err, ts_err)
        if params is not None: make_hist(winners, params)
    return (tr_err,ts_err)

# %% [markdown]
# ## Implementación de Extreme Learning Machine

# %%
def sigmoid(z):
    return 1./(1.+np.exp(-z))

# %%
class ELM(BaseEstimator, ClassifierMixin):
    def __init__(self, n_hidden=10, activation=sigmoid):
        self.n_hidden = n_hidden
        self.activation = activation
    
    def fit(self, X, y):
        #creating a random matrix W with the weights of the hidden layer
        #weights are between -0.5 and 0.5
        M,I = X.shape
        W = np.random.random((I,self.n_hidden))
        W -= 0.5
        #storing it in the object attribute
        self.W = W
        
        #computing output values of hidden nodes
        H = self.activation(np.dot(X,W))
        
        #softmax-logistic regression
        clf = LogisticRegression()
        clf.fit(H,y)
        self.clf = clf
        return self
    
    def predict(self, X):
        H = self.activation(np.dot(X,self.W))
        return self.clf.predict(H)
    
    def score(self, X, y):
        H = self.activation(np.dot(X,self.W))
        return self.clf.score(H,y)

# %% [markdown]
# ## Implementación de Bagging

# %%
class Bagging(BaseEstimator,ClassifierMixin):
    def __init__(self, n_estimators=5, max_depth=1):
        self.n_estimators = n_estimators
        self.max_depth = max_depth
        
    def fit(self, X, y):
        #list where estimators will be stored
        estimators = []
        #indexes of X
        ind = np.arange(X.shape[0])
        #fitting all the classifiers
        for i in xrange(self.n_estimators):
            #bootstraped indexes
            b_ind = resample(ind, replace=True)
            clf = DecisionTree(max_depth=self.max_depth)
            clf.fit(X[b_ind], y[b_ind])
            estimators.append(clf)
        #storing results
        self.estimators = estimators
        return self
    
    def predict(self, X):
        #array with probabilies of classes
        prob = np.zeros((X.shape[0],2))
        for clf in self.estimators:
            prob += clf.predict_proba(X)
        #taking average probability
        prob /= self.n_estimators
        return np.argmax(prob, axis=1)
    
    def score(self, X, y):
        ypred = self.predict(X)
        return precision(y, ypred)
