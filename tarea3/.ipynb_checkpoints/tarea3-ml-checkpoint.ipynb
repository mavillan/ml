params: {'learning_rate_init': 0.0001, 'hidden_layer_sizes': (100,)}
# mean: 0.65451, std: 0.00216, params: {'learning_rate_init': 0.0005, 'hidden_layer_sizes': (100,)}
# mean: 0.65451, std: 0.00503, params: {'learning_rate_init': 0.001, 'hidden_layer_sizes': (100,)}
# mean: 0.76562, std: 0.02541, params: {'learning_rate_init': 0.005, 'hidden_layer_sizes': (100,)}
# Training error: 0.230902777778
# Testing error: 0.239583333333
# ##############################################################
#
#
# ##############################################################
# Dataset: 17
# Best parameter: {'learning_rate_init': 0.005, 'hidden_layer_sizes': (25,)}
# CV scores:
# mean: 0.66493, std: 0.00141, params: {'learning_rate_init': 0.0001, 'hidden_layer_sizes': (25,)}
# mean: 0.66493, std: 0.00141, params: {'learning_rate_init': 0.0005, 'hidden_layer_sizes': (25,)}
# mean: 0.66840, std: 0.00645, params: {'learning_rate_init': 0.001, 'hidden_layer_sizes': (25,)}
# mean: 0.77604, std: 0.03131, params: {'learning_rate_init': 0.005, 'hidden_layer_sizes': (25,)}
# mean: 0.66493, std: 0.00141, params: {'learning_rate_init': 0.0001, 'hidden_layer_sizes': (50,)}
# mean: 0.66493, std: 0.00141, params: {'learning_rate_init': 0.0005, 'hidden_layer_sizes': (50,)}
# mean: 0.66493, std: 0.00141, params: {'learning_rate_init': 0.001, 'hidden_layer_sizes': (50,)}
# mean: 0.77604, std: 0.03131, params: {'learning_rate_init': 0.005, 'hidden_layer_sizes': (50,)}
# mean: 0.66493, std: 0.00141, params: {'learning_rate_init': 0.0001, 'hidden_layer_sizes': (75,)}
# mean: 0.66493, std: 0.00141, params: {'learning_rate_init': 0.0005, 'hidden_layer_sizes': (75,)}
# mean: 0.66319, std: 0.00287, params: {'learning_rate_init': 0.001, 'hidden_layer_sizes': (75,)}
# mean: 0.75174, std: 0.05023, params: {'learning_rate_init': 0.005, 'hidden_layer_sizes': (75,)}
# mean: 0.66493, std: 0.00141, params: {'learning_rate_init': 0.0001, 'hidden_layer_sizes': (100,)}
# mean: 0.66493, std: 0.00141, params: {'learning_rate_init': 0.0005, 'hidden_layer_sizes': (100,)}
# mean: 0.66493, std: 0.00141, params: {'learning_rate_init': 0.001, 'hidden_layer_sizes': (100,)}
# mean: 0.76562, std: 0.05471, params: {'learning_rate_init': 0.005, 'hidden_layer_sizes': (100,)}
# Training error: 0.213541666667
# Testing error: 0.291666666667
# ##############################################################
#
#
# ##############################################################
# Dataset: 18
# Best parameter: {'learning_rate_init': 0.005, 'hidden_layer_sizes': (50,)}
# CV scores:
# mean: 0.64583, std: 0.00214, params: {'learning_rate_init': 0.0001, 'hidden_layer_sizes': (25,)}
# mean: 0.64583, std: 0.00214, params: {'learning_rate_init': 0.0005, 'hidden_layer_sizes': (25,)}
# mean: 0.64757, std: 0.00435, params: {'learning_rate_init': 0.001, 'hidden_layer_sizes': (25,)}
# mean: 0.76736, std: 0.01027, params: {'learning_rate_init': 0.005, 'hidden_layer_sizes': (25,)}
# mean: 0.64583, std: 0.00214, params: {'learning_rate_init': 0.0001, 'hidden_layer_sizes': (50,)}
# mean: 0.64583, std: 0.00214, params: {'learning_rate_init': 0.0005, 'hidden_layer_sizes': (50,)}
# mean: 0.64410, std: 0.00374, params: {'learning_rate_init': 0.001, 'hidden_layer_sizes': (50,)}
# mean: 0.77257, std: 0.01409, params: {'learning_rate_init': 0.005, 'hidden_layer_sizes': (50,)}
# mean: 0.64583, std: 0.00214, params: {'learning_rate_init': 0.0001, 'hidden_layer_sizes': (75,)}
# mean: 0.64583, std: 0.00214, params: {'learning_rate_init': 0.0005, 'hidden_layer_sizes': (75,)}
# mean: 0.64583, std: 0.00214, params: {'learning_rate_init': 0.001, 'hidden_layer_sizes': (75,)}
# mean: 0.73958, std: 0.04947, params: {'learning_rate_init': 0.005, 'hidden_layer_sizes': (75,)}
# mean: 0.64583, std: 0.00214, params: {'learning_rate_init': 0.0001, 'hidden_layer_sizes': (100,)}
# mean: 0.64583, std: 0.00214, params: {'learning_rate_init': 0.0005, 'hidden_layer_sizes': (100,)}
# mean: 0.64410, std: 0.00374, params: {'learning_rate_init': 0.001, 'hidden_layer_sizes': (100,)}
# mean: 0.67535, std: 0.05902, params: {'learning_rate_init': 0.005, 'hidden_layer_sizes': (100,)}
# Training error: 0.234375
# Testing error: 0.223958333333
# ##############################################################
#
#
# ##############################################################
# Dataset: 19
# Best parameter: {'learning_rate_init': 0.005, 'hidden_layer_sizes': (25,)}
# CV scores:
# mean: 0.65972, std: 0.00228, params: {'learning_rate_init': 0.0001, 'hidden_layer_sizes': (25,)}
# mean: 0.65972, std: 0.00228, params: {'learning_rate_init': 0.0005, 'hidden_layer_sizes': (25,)}
# mean: 0.65972, std: 0.00228, params: {'learning_rate_init': 0.001, 'hidden_layer_sizes': (25,)}
# mean: 0.76736, std: 0.02877, params: {'learning_rate_init': 0.005, 'hidden_layer_sizes': (25,)}
# mean: 0.65972, std: 0.00228, params: {'learning_rate_init': 0.0001, 'hidden_layer_sizes': (50,)}
# mean: 0.65972, std: 0.00228, params: {'learning_rate_init': 0.0005, 'hidden_layer_sizes': (50,)}
# mean: 0.65972, std: 0.00228, params: {'learning_rate_init': 0.001, 'hidden_layer_sizes': (50,)}
# mean: 0.71701, std: 0.04953, params: {'learning_rate_init': 0.005, 'hidden_layer_sizes': (50,)}
# mean: 0.65972, std: 0.00228, params: {'learning_rate_init': 0.0001, 'hidden_layer_sizes': (75,)}
# mean: 0.65972, std: 0.00228, params: {'learning_rate_init': 0.0005, 'hidden_layer_sizes': (75,)}
# mean: 0.65972, std: 0.00228, params: {'learning_rate_init': 0.001, 'hidden_layer_sizes': (75,)}
# mean: 0.72049, std: 0.05017, params: {'learning_rate_init': 0.005, 'hidden_layer_sizes': (75,)}
# mean: 0.65972, std: 0.00228, params: {'learning_rate_init': 0.0001, 'hidden_layer_sizes': (100,)}
# mean: 0.65799, std: 0.00573, params: {'learning_rate_init': 0.0005, 'hidden_layer_sizes': (100,)}
# mean: 0.65972, std: 0.00228, params: {'learning_rate_init': 0.001, 'hidden_layer_sizes': (100,)}
# mean: 0.72743, std: 0.05786, params: {'learning_rate_init': 0.005, 'hidden_layer_sizes': (100,)}
# Training error: 0.232638888889
# Testing error: 0.223958333333
# ##############################################################
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-25-d92df05d124d> in <module>()
#       1 mlp = MLPClassifier(activation='logistic', algorithm='sgd', learning_rate='constant')
# ----> 2 mlp_tr_err, mlp_ts_err = solve_clf(mlp, params=mlp_params, show=range(20))
#
# <ipython-input-18-5e57c846ea66> in solve_clf(clf, params, grid, scale, show)
#     116     if show:
#     117         plot_error(tr_err, ts_err)
# --> 118         if params is not None: make_hist(winners, params)
#     119     return (tr_err,ts_err)
#
# <ipython-input-18-5e57c846ea66> in make_hist(winners, params)
#       8         freqs = np.zeros(5)
#       9         for i in xrange(5):
# ---> 10             freqs[i] = np.sum(par[i]==win)
#      11         labels = map(str,par)
#      12         pos = np.arange(len(labels))
#
# IndexError: list index out of range

# %% [markdown]
# ## Anexo de Código

# %% [markdown]
# **Observación:** Para la correcta ejecución del código en el informe, primero se deben ejecutar las celdas del anexo de código aquí abajo.

# %% [markdown]
# ### Configuración del notebook

# %%
#notebook settings
# %matplotlib inline

#import some useful libraries and utilities
import numpy as np
import matplotlib.cm as cm
import matplotlib.pyplot as plt
from sklearn.grid_search import GridSearchCV
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.utils import resample
from sklearn.tree import DecisionTreeClassifier as DecisionTree
from sklearn.ensemble import AdaBoostClassifier as AdaBoost

# %% [markdown]
# ### Configuración del notebook

# %% [markdown]
# ## Métricas de error para clasificación

# %%
#precision
def precision(yreal, ypred):
    yr = yreal.astype(int)
    yp = ypred.astype(int) 
    m, = yr.shape
    #number of good predictions/number of predictions
    return np.sum(yp==yr)/float(m)

#error rate 
def error_rate(yreal, ypred):
    return 1.-precision(yreal, ypred)

# %% [markdown]
# ## Funciones complementarias (helpers) para obtener resultados

# %%
"""
Function to generate histogram of winners
"""
def make_hist(winners,params):
    for key in winners:
        par = params[key]
        win = np.array(winners[key])
        freqs = np.zeros(5)
        for i in xrange(5):
            freqs[i] = np.sum(par[i]==win)
        labels = map(str,par)
        pos = np.arange(len(labels))
        width = 1.0
        fig = plt.figure()
        fig.set_figheight(5)
        fig.set_figwidth(5)
        ax = plt.axes()
        ax.set_xticks(pos + (width / 2))
        ax.set_xticklabels(labels)
        plt.xlabel('Parameters')
        plt.ylabel('Frequency')
        plt.title('Histogram of {0}'.format(key))
        plt.bar(pos, freqs, width, color='0.5')
        plt.show()
    
def plot_error(tr_err, ts_err):
    x = np.arange(20)
    plt.figure(figsize=(12,6))
    plt.plot(x, tr_err, marker='o', linestyle='--', color='b', label='Training Error')
    plt.plot(x, ts_err, marker='o', linestyle='--', color='r', label='Testing Error')
    plt.xlabel('Datasets')
    plt.ylabel('Error Rate')
    plt.title('Training and testing error rates in each dataset')
    plt.legend(bbox_to_anchor=(1.25, 1.0))
    plt.show()
    
def comparative_plot(errors, labels, err_type=None):
    x = np.arange(20)
    colors = cm.rainbow(np.linspace(0., 1., len(errors)))
    plt.figure(figsize=(12,6))
    for i in xrange(len(errors)):
        plt.plot(x, errors[i], marker='o', linestyle='--', color=colors[i], label=labels[i])
    plt.xlabel('Datasets')
    plt.ylabel(err_type+' error rates')
    plt.legend(bbox_to_anchor=(1.25, 1.0))
    plt.show()    

"""
Generate solutions for classification problems
"""
def solve_clf(clf, params=None, grid=None, scale=True, show=None):
    if params is not None:
        winners = dict()
        for key in params:
            winners[key] = list()
            
    #set dataset name
    path = './diabetes/diabetes'
    
    #error-rates to plot
    tr_err = np.empty(20)
    ts_err = np.empty(20)
    
    #iterate through data
    for i in xrange(20):
        #loading datasets
        tr_file = path+'-tr-{0}.npy'.format(i)
        ts_file = path+'-ts-{0}.npy'.format(i)
            
        tr_data = np.load(tr_file)
        ts_data = np.load(ts_file)
        
        if scale:
            #perform same scaling on training and testing sets
            scaler = StandardScaler()
            scaler.fit(tr_data[:,:-1])
            X_tr = scaler.transform(tr_data[:,:-1])
            X_ts = scaler.transform(ts_data[:,:-1])
        else: 
            X_tr = tr_data[:,:-1]
            X_ts = ts_data[:,:-1]
        y_tr = np.ascontiguousarray(tr_data[:,-1])
        y_ts = np.ascontiguousarray(ts_data[:,-1])

        if params is not None:
            #tunning parameters
            gs = GridSearchCV(clf, params, cv=5, n_jobs=2)
            gs.fit(X_tr, y_tr)
            grid_scores = gs.grid_scores_
            best_params = gs.best_params_
            for key in winners:
                winners[key].append(best_params[key])
            #traininig with best parameters
            clf.set_params(**best_params)
            clf.fit(X_tr, y_tr)
        else:
            clf.fit(X_tr, y_tr)
        
        #computing errors
        tr_err[i] = error_rate(y_tr, clf.predict(X_tr))
        ts_err[i] = error_rate(y_ts, clf.predict(X_ts))
        
        if (show is not None) and (i not in show): continue
        print "##############################################################"
        print "Dataset: {0}".format(i)
        if params is not None:
            print 'Best parameter: {0}'.format(best_params)
            print 'CV scores:'
            for result in grid_scores: print result
        print 'Training error: {0}'.format(tr_err[i])
        print 'Testing error: {0}'.format(ts_err[i])
        print "##############################################################"
        print '\n'
    
    #ploting errors
    if show: 
        plot_error(tr_err, ts_err)
        #if params is not None: make_hist(winners, params)
    return (tr_err,ts_err)

# %% [markdown]
# ## Implementación de Bagging

# %%
class Bagging(BaseEstimator,ClassifierMixin):
    def __init__(self, n_estimators=5, max_depth=1):
        self.n_estimators = n_estimators
        self.max_depth = max_depth
        
    def fit(self, X, y):
        #list where estimators will be stored
        estimators = []
        #indexes of X
        ind = np.arange(X.shape[0])
        #fitting all the classifiers
        for i in xrange(self.n_estimators):
            #bootstraped indexes
            b_ind = resample(ind, replace=True)
            clf = DecisionTree(max_depth=self.max_depth)
            clf.fit(X[b_ind], y[b_ind])
            estimators.append(clf)
        #storing results
        self.estimators = estimators
        return self
    
    def predict(self, X):
        #array with probabilies of classes
        prob = np.zeros((X.shape[0],2))
        for clf in self.estimators:
            prob += clf.predict_proba(X)
        #taking average probability
        prob /= self.n_estimators
        return np.argmax(prob, axis=1)
    
    def score(self, X, y):
        ypred = self.predict(X)
        return precision(y, ypred)

# %%
X = np.random.random((100,5))
y = np.random.random(100)
y = (y > 0.5).astype(int)

# %%
clf = Bagging(max_depth=5, n_estimators=20)
clf.fit(X,y)
# Out:
# Bagging(max_depth=5, n_estimators=20)

# %%
clf.score(X,y)
# Out:
# 0.93999999999999995
