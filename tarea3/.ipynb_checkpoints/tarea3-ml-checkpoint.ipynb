# %% [markdown]
# # Tarea N°3 - Máquinas de Aprendizaje - ILI393
# ### Martín Villanueva A.

# %% [markdown]
# ## Feedforward ANN sin weight decay

# %%
#parameters to try on MPL
mlp_params = {'hidden_layer_sizes':[(25,),(50,),(75,),(100,),(125)], 'learning_rate_init':[0.05, 0.075, 0.1, 0.125, 0.15]}

# %%
mlp = MLPClassifier(activation='logistic', algorithm='sgd', learning_rate='constant', alpha=0.)
mlp_tr_err, mlp_ts_err = solve_clf(mlp, params=mlp_params, show=range(20))
# Out:
# ##############################################################
# Dataset: 0
# Best parameter: {'learning_rate_init': 0.125, 'hidden_layer_sizes': 125}
# CV scores:
# mean: 0.76042, std: 0.04803, params: {'learning_rate_init': 0.05, 'hidden_layer_sizes': (25,)}
# mean: 0.76736, std: 0.03260, params: {'learning_rate_init': 0.075, 'hidden_layer_sizes': (25,)}
# mean: 0.76562, std: 0.03880, params: {'learning_rate_init': 0.1, 'hidden_layer_sizes': (25,)}
# mean: 0.76042, std: 0.03402, params: {'learning_rate_init': 0.125, 'hidden_layer_sizes': (25,)}
# mean: 0.76562, std: 0.04061, params: {'learning_rate_init': 0.15, 'hidden_layer_sizes': (25,)}
# mean: 0.77083, std: 0.04113, params: {'learning_rate_init': 0.05, 'hidden_layer_sizes': (50,)}
# mean: 0.76389, std: 0.04476, params: {'learning_rate_init': 0.075, 'hidden_layer_sizes': (50,)}
# mean: 0.76910, std: 0.03267, params: {'learning_rate_init': 0.1, 'hidden_layer_sizes': (50,)}
# mean: 0.77604, std: 0.03372, params: {'learning_rate_init': 0.125, 'hidden_layer_sizes': (50,)}
# mean: 0.76215, std: 0.03819, params: {'learning_rate_init': 0.15, 'hidden_layer_sizes': (50,)}
# mean: 0.76562, std: 0.04079, params: {'learning_rate_init': 0.05, 'hidden_layer_sizes': (75,)}
# mean: 0.76215, std: 0.04329, params: {'learning_rate_init': 0.075, 'hidden_layer_sizes': (75,)}
# mean: 0.76736, std: 0.03527, params: {'learning_rate_init': 0.1, 'hidden_layer_sizes': (75,)}
# mean: 0.77431, std: 0.03690, params: {'learning_rate_init': 0.125, 'hidden_layer_sizes': (75,)}
# mean: 0.76736, std: 0.03864, params: {'learning_rate_init': 0.15, 'hidden_layer_sizes': (75,)}
# mean: 0.76389, std: 0.03954, params: {'learning_rate_init': 0.05, 'hidden_layer_sizes': (100,)}
# mean: 0.76042, std: 0.03688, params: {'learning_rate_init': 0.075, 'hidden_layer_sizes': (100,)}
# mean: 0.77257, std: 0.04304, params: {'learning_rate_init': 0.1, 'hidden_layer_sizes': (100,)}
# mean: 0.76215, std: 0.04248, params: {'learning_rate_init': 0.125, 'hidden_layer_sizes': (100,)}
# mean: 0.75174, std: 0.04207, params: {'learning_rate_init': 0.15, 'hidden_layer_sizes': (100,)}
# mean: 0.75521, std: 0.04467, params: {'learning_rate_init': 0.05, 'hidden_layer_sizes': 125}
# mean: 0.77083, std: 0.03809, params: {'learning_rate_init': 0.075, 'hidden_layer_sizes': 125}
# mean: 0.76736, std: 0.02851, params: {'learning_rate_init': 0.1, 'hidden_layer_sizes': 125}
# mean: 0.77778, std: 0.04163, params: {'learning_rate_init': 0.125, 'hidden_layer_sizes': 125}
# mean: 0.76042, std: 0.04568, params: {'learning_rate_init': 0.15, 'hidden_layer_sizes': 125}
# Training error: 0.210069444444
# Testing error: 0.244791666667
# ##############################################################
#
#
# ##############################################################
# Dataset: 1
# Best parameter: {'learning_rate_init': 0.125, 'hidden_layer_sizes': (25,)}
# CV scores:
# mean: 0.76389, std: 0.03488, params: {'learning_rate_init': 0.05, 'hidden_layer_sizes': (25,)}
# mean: 0.75174, std: 0.03266, params: {'learning_rate_init': 0.075, 'hidden_layer_sizes': (25,)}
# mean: 0.75868, std: 0.03735, params: {'learning_rate_init': 0.1, 'hidden_layer_sizes': (25,)}
# mean: 0.76910, std: 0.03125, params: {'learning_rate_init': 0.125, 'hidden_layer_sizes': (25,)}
# mean: 0.76215, std: 0.03839, params: {'learning_rate_init': 0.15, 'hidden_layer_sizes': (25,)}
# mean: 0.75347, std: 0.03085, params: {'learning_rate_init': 0.05, 'hidden_layer_sizes': (50,)}
# mean: 0.75694, std: 0.02792, params: {'learning_rate_init': 0.075, 'hidden_layer_sizes': (50,)}
# mean: 0.75347, std: 0.03584, params: {'learning_rate_init': 0.1, 'hidden_layer_sizes': (50,)}
# mean: 0.75521, std: 0.02721, params: {'learning_rate_init': 0.125, 'hidden_layer_sizes': (50,)}
# mean: 0.75868, std: 0.02528, params: {'learning_rate_init': 0.15, 'hidden_layer_sizes': (50,)}
# mean: 0.75174, std: 0.01697, params: {'learning_rate_init': 0.05, 'hidden_layer_sizes': (75,)}
# mean: 0.76042, std: 0.02004, params: {'learning_rate_init': 0.075, 'hidden_layer_sizes': (75,)}
# mean: 0.74826, std: 0.03112, params: {'learning_rate_init': 0.1, 'hidden_layer_sizes': (75,)}
# mean: 0.74826, std: 0.03607, params: {'learning_rate_init': 0.125, 'hidden_layer_sizes': (75,)}
# mean: 0.75174, std: 0.04443, params: {'learning_rate_init': 0.15, 'hidden_layer_sizes': (75,)}
# mean: 0.76042, std: 0.03761, params: {'learning_rate_init': 0.05, 'hidden_layer_sizes': (100,)}
# mean: 0.76042, std: 0.02765, params: {'learning_rate_init': 0.075, 'hidden_layer_sizes': (100,)}
# mean: 0.76389, std: 0.02922, params: {'learning_rate_init': 0.1, 'hidden_layer_sizes': (100,)}
# mean: 0.75868, std: 0.03864, params: {'learning_rate_init': 0.125, 'hidden_layer_sizes': (100,)}
# mean: 0.75347, std: 0.02947, params: {'learning_rate_init': 0.15, 'hidden_layer_sizes': (100,)}
# mean: 0.75000, std: 0.03165, params: {'learning_rate_init': 0.05, 'hidden_layer_sizes': 125}
# mean: 0.75521, std: 0.02283, params: {'learning_rate_init': 0.075, 'hidden_layer_sizes': 125}
# mean: 0.75347, std: 0.02947, params: {'learning_rate_init': 0.1, 'hidden_layer_sizes': 125}
# mean: 0.75521, std: 0.03229, params: {'learning_rate_init': 0.125, 'hidden_layer_sizes': 125}
# mean: 0.76042, std: 0.03670, params: {'learning_rate_init': 0.15, 'hidden_layer_sizes': 125}
# Training error: 0.230902777778
# Testing error: 0.1875
# ##############################################################
#
#
# ##############################################################
# Dataset: 2
# Best parameter: {'learning_rate_init': 0.125, 'hidden_layer_sizes': (50,)}
# CV scores:
# mean: 0.78993, std: 0.03439, params: {'learning_rate_init': 0.05, 'hidden_layer_sizes': (25,)}
# mean: 0.78472, std: 0.03473, params: {'learning_rate_init': 0.075, 'hidden_layer_sizes': (25,)}
# mean: 0.78646, std: 0.03305, params: {'learning_rate_init': 0.1, 'hidden_layer_sizes': (25,)}
# mean: 0.78472, std: 0.03748, params: {'learning_rate_init': 0.125, 'hidden_layer_sizes': (25,)}
# mean: 0.78472, std: 0.03920, params: {'learning_rate_init': 0.15, 'hidden_layer_sizes': (25,)}
# mean: 0.77951, std: 0.02854, params: {'learning_rate_init': 0.05, 'hidden_layer_sizes': (50,)}
# mean: 0.78819, std: 0.03038, params: {'learning_rate_init': 0.075, 'hidden_layer_sizes': (50,)}
# mean: 0.78646, std: 0.02968, params: {'learning_rate_init': 0.1, 'hidden_layer_sizes': (50,)}
# mean: 0.79688, std: 0.03060, params: {'learning_rate_init': 0.125, 'hidden_layer_sizes': (50,)}
# mean: 0.78125, std: 0.03848, params: {'learning_rate_init': 0.15, 'hidden_layer_sizes': (50,)}
# mean: 0.79167, std: 0.02257, params: {'learning_rate_init': 0.05, 'hidden_layer_sizes': (75,)}
# mean: 0.78125, std: 0.03112, params: {'learning_rate_init': 0.075, 'hidden_layer_sizes': (75,)}
# mean: 0.78819, std: 0.03060, params: {'learning_rate_init': 0.1, 'hidden_layer_sizes': (75,)}
# mean: 0.77257, std: 0.03617, params: {'learning_rate_init': 0.125, 'hidden_layer_sizes': (75,)}
# mean: 0.77778, std: 0.02477, params: {'learning_rate_init': 0.15, 'hidden_layer_sizes': (75,)}
# mean: 0.78472, std: 0.02435, params: {'learning_rate_init': 0.05, 'hidden_layer_sizes': (100,)}
# mean: 0.77951, std: 0.02455, params: {'learning_rate_init': 0.075, 'hidden_layer_sizes': (100,)}
# mean: 0.77431, std: 0.02559, params: {'learning_rate_init': 0.1, 'hidden_layer_sizes': (100,)}
# mean: 0.78646, std: 0.02367, params: {'learning_rate_init': 0.125, 'hidden_layer_sizes': (100,)}
# mean: 0.77257, std: 0.02270, params: {'learning_rate_init': 0.15, 'hidden_layer_sizes': (100,)}
# mean: 0.78299, std: 0.02709, params: {'learning_rate_init': 0.05, 'hidden_layer_sizes': 125}
# mean: 0.78819, std: 0.02565, params: {'learning_rate_init': 0.075, 'hidden_layer_sizes': 125}
# mean: 0.78819, std: 0.03129, params: {'learning_rate_init': 0.1, 'hidden_layer_sizes': 125}
# mean: 0.77431, std: 0.03586, params: {'learning_rate_init': 0.125, 'hidden_layer_sizes': 125}
# mean: 0.76215, std: 0.03578, params: {'learning_rate_init': 0.15, 'hidden_layer_sizes': 125}
# Training error: 0.208333333333
# Testing error: 0.25
# ##############################################################
#
#
# ##############################################################
# Dataset: 3
# Best parameter: {'learning_rate_init': 0.075, 'hidden_layer_sizes': (100,)}
# CV scores:
# mean: 0.77951, std: 0.02914, params: {'learning_rate_init': 0.05, 'hidden_layer_sizes': (25,)}
# mean: 0.78125, std: 0.02111, params: {'learning_rate_init': 0.075, 'hidden_layer_sizes': (25,)}
# mean: 0.77083, std: 0.02282, params: {'learning_rate_init': 0.1, 'hidden_layer_sizes': (25,)}
# mean: 0.77083, std: 0.02409, params: {'learning_rate_init': 0.125, 'hidden_layer_sizes': (25,)}
# mean: 0.77431, std: 0.02349, params: {'learning_rate_init': 0.15, 'hidden_layer_sizes': (25,)}
# mean: 0.77083, std: 0.03445, params: {'learning_rate_init': 0.05, 'hidden_layer_sizes': (50,)}
# mean: 0.76910, std: 0.03018, params: {'learning_rate_init': 0.075, 'hidden_layer_sizes': (50,)}
# mean: 0.78125, std: 0.01717, params: {'learning_rate_init': 0.1, 'hidden_layer_sizes': (50,)}
# mean: 0.78125, std: 0.02290, params: {'learning_rate_init': 0.125, 'hidden_layer_sizes': (50,)}
# mean: 0.76910, std: 0.03463, params: {'learning_rate_init': 0.15, 'hidden_layer_sizes': (50,)}
# mean: 0.77604, std: 0.01469, params: {'learning_rate_init': 0.05, 'hidden_layer_sizes': (75,)}
# mean: 0.76736, std: 0.03076, params: {'learning_rate_init': 0.075, 'hidden_layer_sizes': (75,)}
# mean: 0.77431, std: 0.03267, params: {'learning_rate_init': 0.1, 'hidden_layer_sizes': (75,)}
# mean: 0.77778, std: 0.01295, params: {'learning_rate_init': 0.125, 'hidden_layer_sizes': (75,)}
# mean: 0.76910, std: 0.03712, params: {'learning_rate_init': 0.15, 'hidden_layer_sizes': (75,)}
# mean: 0.77604, std: 0.02098, params: {'learning_rate_init': 0.05, 'hidden_layer_sizes': (100,)}
# mean: 0.78299, std: 0.01975, params: {'learning_rate_init': 0.075, 'hidden_layer_sizes': (100,)}
# mean: 0.77604, std: 0.01055, params: {'learning_rate_init': 0.1, 'hidden_layer_sizes': (100,)}
# mean: 0.77778, std: 0.01790, params: {'learning_rate_init': 0.125, 'hidden_layer_sizes': (100,)}
# mean: 0.76562, std: 0.04001, params: {'learning_rate_init': 0.15, 'hidden_layer_sizes': (100,)}
# mean: 0.77257, std: 0.01524, params: {'learning_rate_init': 0.05, 'hidden_layer_sizes': 125}
# mean: 0.76562, std: 0.02329, params: {'learning_rate_init': 0.075, 'hidden_layer_sizes': 125}
# mean: 0.78125, std: 0.01713, params: {'learning_rate_init': 0.1, 'hidden_layer_sizes': 125}
# mean: 0.77778, std: 0.02429, params: {'learning_rate_init': 0.125, 'hidden_layer_sizes': 125}
# mean: 0.77778, std: 0.01143, params: {'learning_rate_init': 0.15, 'hidden_layer_sizes': 125}
# Training error: 0.215277777778
# Testing error: 0.229166666667
# ##############################################################
#
#
# ##############################################################
# Dataset: 4
# Best parameter: {'learning_rate_init': 0.05, 'hidden_layer_sizes': (25,)}
# CV scores:
# mean: 0.77604, std: 0.02746, params: {'learning_rate_init': 0.05, 'hidden_layer_sizes': (25,)}
# mean: 0.76389, std: 0.01257, params: {'learning_rate_init': 0.075, 'hidden_layer_sizes': (25,)}
# mean: 0.76215, std: 0.02048, params: {'learning_rate_init': 0.1, 'hidden_layer_sizes': (25,)}
# mean: 0.76562, std: 0.02286, params: {'learning_rate_init': 0.125, 'hidden_layer_sizes': (25,)}
# mean: 0.76910, std: 0.02235, params: {'learning_rate_init': 0.15, 'hidden_layer_sizes': (25,)}
# mean: 0.76910, std: 0.02578, params: {'learning_rate_init': 0.05, 'hidden_layer_sizes': (50,)}
# mean: 0.76562, std: 0.01486, params: {'learning_rate_init': 0.075, 'hidden_layer_sizes': (50,)}
# mean: 0.77083, std: 0.02035, params: {'learning_rate_init': 0.1, 'hidden_layer_sizes': (50,)}
# mean: 0.76910, std: 0.02727, params: {'learning_rate_init': 0.125, 'hidden_layer_sizes': (50,)}
# mean: 0.75868, std: 0.02340, params: {'learning_rate_init': 0.15, 'hidden_layer_sizes': (50,)}
# mean: 0.75868, std: 0.02078, params: {'learning_rate_init': 0.05, 'hidden_layer_sizes': (75,)}
# mean: 0.76389, std: 0.01863, params: {'learning_rate_init': 0.075, 'hidden_layer_sizes': (75,)}
# mean: 0.75000, std: 0.02922, params: {'learning_rate_init': 0.1, 'hidden_layer_sizes': (75,)}
# mean: 0.76736, std: 0.01993, params: {'learning_rate_init': 0.125, 'hidden_layer_sizes': (75,)}
# mean: 0.75000, std: 0.02463, params: {'learning_rate_init': 0.15, 'hidden_layer_sizes': (75,)}
# mean: 0.76910, std: 0.01477, params: {'learning_rate_init': 0.05, 'hidden_layer_sizes': (100,)}
# mean: 0.76562, std: 0.02321, params: {'learning_rate_init': 0.075, 'hidden_layer_sizes': (100,)}
# mean: 0.75868, std: 0.02576, params: {'learning_rate_init': 0.1, 'hidden_layer_sizes': (100,)}
# mean: 0.74479, std: 0.04178, params: {'learning_rate_init': 0.125, 'hidden_layer_sizes': (100,)}
# mean: 0.74826, std: 0.01874, params: {'learning_rate_init': 0.15, 'hidden_layer_sizes': (100,)}
# mean: 0.77431, std: 0.01997, params: {'learning_rate_init': 0.05, 'hidden_layer_sizes': 125}
# mean: 0.75174, std: 0.02838, params: {'learning_rate_init': 0.075, 'hidden_layer_sizes': 125}
# mean: 0.76562, std: 0.01603, params: {'learning_rate_init': 0.1, 'hidden_layer_sizes': 125}
# mean: 0.76736, std: 0.02391, params: {'learning_rate_init': 0.125, 'hidden_layer_sizes': 125}
# mean: 0.75521, std: 0.02018, params: {'learning_rate_init': 0.15, 'hidden_layer_sizes': 125}
# Training error: 0.21875
# Testing error: 0.213541666667
# ##############################################################
#
#
# ##############################################################
# Dataset: 5
# Best parameter: {'learning_rate_init': 0.125, 'hidden_layer_sizes': (25,)}
# CV scores:
# mean: 0.78299, std: 0.02793, params: {'learning_rate_init': 0.05, 'hidden_layer_sizes': (25,)}
# mean: 0.77778, std: 0.03491, params: {'learning_rate_init': 0.075, 'hidden_layer_sizes': (25,)}
# mean: 0.78299, std: 0.03040, params: {'learning_rate_init': 0.1, 'hidden_layer_sizes': (25,)}
# mean: 0.78646, std: 0.02779, params: {'learning_rate_init': 0.125, 'hidden_layer_sizes': (25,)}
# mean: 0.78125, std: 0.03074, params: {'learning_rate_init': 0.15, 'hidden_layer_sizes': (25,)}
# mean: 0.78299, std: 0.02568, params: {'learning_rate_init': 0.05, 'hidden_layer_sizes': (50,)}
# mean: 0.77604, std: 0.02784, params: {'learning_rate_init': 0.075, 'hidden_layer_sizes': (50,)}
# mean: 0.78299, std: 0.03760, params: {'learning_rate_init': 0.1, 'hidden_layer_sizes': (50,)}
# mean: 0.78472, std: 0.02758, params: {'learning_rate_init': 0.125, 'hidden_layer_sizes': (50,)}
# mean: 0.78299, std: 0.03630, params: {'learning_rate_init': 0.15, 'hidden_layer_sizes': (50,)}
# mean: 0.77778, std: 0.02977, params: {'learning_rate_init': 0.05, 'hidden_layer_sizes': (75,)}
# mean: 0.78125, std: 0.02376, params: {'learning_rate_init': 0.075, 'hidden_layer_sizes': (75,)}
# mean: 0.78125, std: 0.02548, params: {'learning_rate_init': 0.1, 'hidden_layer_sizes': (75,)}
# mean: 0.77431, std: 0.02805, params: {'learning_rate_init': 0.125, 'hidden_layer_sizes': (75,)}
# mean: 0.78299, std: 0.04712, params: {'learning_rate_init': 0.15, 'hidden_layer_sizes': (75,)}
# mean: 0.77083, std: 0.02803, params: {'learning_rate_init': 0.05, 'hidden_layer_sizes': (100,)}
# mean: 0.76736, std: 0.03188, params: {'learning_rate_init': 0.075, 'hidden_layer_sizes': (100,)}
# mean: 0.76736, std: 0.03492, params: {'learning_rate_init': 0.1, 'hidden_layer_sizes': (100,)}
# mean: 0.76389, std: 0.02905, params: {'learning_rate_init': 0.125, 'hidden_layer_sizes': (100,)}
# mean: 0.77951, std: 0.02896, params: {'learning_rate_init': 0.15, 'hidden_layer_sizes': (100,)}
# mean: 0.77778, std: 0.02236, params: {'learning_rate_init': 0.05, 'hidden_layer_sizes': 125}
# mean: 0.77778, std: 0.02833, params: {'learning_rate_init': 0.075, 'hidden_layer_sizes': 125}
# mean: 0.76389, std: 0.02332, params: {'learning_rate_init': 0.1, 'hidden_layer_sizes': 125}
# mean: 0.75347, std: 0.04831, params: {'learning_rate_init': 0.125, 'hidden_layer_sizes': 125}
# mean: 0.76562, std: 0.02535, params: {'learning_rate_init': 0.15, 'hidden_layer_sizes': 125}
# Training error: 0.204861111111
# Testing error: 0.25
# ##############################################################
#
#
# ##############################################################
# Dataset: 6
# Best parameter: {'learning_rate_init': 0.125, 'hidden_layer_sizes': (100,)}
# CV scores:
# mean: 0.76562, std: 0.02610, params: {'learning_rate_init': 0.05, 'hidden_layer_sizes': (25,)}
# mean: 0.76910, std: 0.01826, params: {'learning_rate_init': 0.075, 'hidden_layer_sizes': (25,)}
# mean: 0.76736, std: 0.02794, params: {'learning_rate_init': 0.1, 'hidden_layer_sizes': (25,)}
# mean: 0.76562, std: 0.02950, params: {'learning_rate_init': 0.125, 'hidden_layer_sizes': (25,)}
# mean: 0.75347, std: 0.03432, params: {'learning_rate_init': 0.15, 'hidden_layer_sizes': (25,)}
# mean: 0.76910, std: 0.02079, params: {'learning_rate_init': 0.05, 'hidden_layer_sizes': (50,)}
# mean: 0.76562, std: 0.02818, params: {'learning_rate_init': 0.075, 'hidden_layer_sizes': (50,)}
# mean: 0.76389, std: 0.02762, params: {'learning_rate_init': 0.1, 'hidden_layer_sizes': (50,)}
# mean: 0.77257, std: 0.03635, params: {'learning_rate_init': 0.125, 'hidden_layer_sizes': (50,)}
# mean: 0.76910, std: 0.02492, params: {'learning_rate_init': 0.15, 'hidden_layer_sizes': (50,)}
# mean: 0.76910, std: 0.02911, params: {'learning_rate_init': 0.05, 'hidden_layer_sizes': (75,)}
# mean: 0.77083, std: 0.01903, params: {'learning_rate_init': 0.075, 'hidden_layer_sizes': (75,)}
# mean: 0.77083, std: 0.02608, params: {'learning_rate_init': 0.1, 'hidden_layer_sizes': (75,)}
# mean: 0.76736, std: 0.02851, params: {'learning_rate_init': 0.125, 'hidden_layer_sizes': (75,)}
# mean: 0.77257, std: 0.03648, params: {'learning_rate_init': 0.15, 'hidden_layer_sizes': (75,)}
# mean: 0.76389, std: 0.03011, params: {'learning_rate_init': 0.05, 'hidden_layer_sizes': (100,)}
# mean: 0.77257, std: 0.02870, params: {'learning_rate_init': 0.075, 'hidden_layer_sizes': (100,)}
# mean: 0.77257, std: 0.02664, params: {'learning_rate_init': 0.1, 'hidden_layer_sizes': (100,)}
# mean: 0.77431, std: 0.01984, params: {'learning_rate_init': 0.125, 'hidden_layer_sizes': (100,)}
# mean: 0.77083, std: 0.03058, params: {'learning_rate_init': 0.15, 'hidden_layer_sizes': (100,)}
# mean: 0.76736, std: 0.02851, params: {'learning_rate_init': 0.05, 'hidden_layer_sizes': 125}
# mean: 0.77431, std: 0.03587, params: {'learning_rate_init': 0.075, 'hidden_layer_sizes': 125}
# mean: 0.77083, std: 0.02474, params: {'learning_rate_init': 0.1, 'hidden_layer_sizes': 125}
# mean: 0.76910, std: 0.02055, params: {'learning_rate_init': 0.125, 'hidden_layer_sizes': 125}
# mean: 0.76215, std: 0.03400, params: {'learning_rate_init': 0.15, 'hidden_layer_sizes': 125}
# Training error: 0.213541666667
# Testing error: 0.234375
# ##############################################################
#
#
# ##############################################################
# Dataset: 7
# Best parameter: {'learning_rate_init': 0.15, 'hidden_layer_sizes': (100,)}
# CV scores:
# mean: 0.77257, std: 0.04031, params: {'learning_rate_init': 0.05, 'hidden_layer_sizes': (25,)}
# mean: 0.78125, std: 0.04755, params: {'learning_rate_init': 0.075, 'hidden_layer_sizes': (25,)}
# mean: 0.77951, std: 0.04817, params: {'learning_rate_init': 0.1, 'hidden_layer_sizes': (25,)}
# mean: 0.77604, std: 0.04536, params: {'learning_rate_init': 0.125, 'hidden_layer_sizes': (25,)}
# mean: 0.78125, std: 0.04425, params: {'learning_rate_init': 0.15, 'hidden_layer_sizes': (25,)}
# mean: 0.77431, std: 0.04568, params: {'learning_rate_init': 0.05, 'hidden_layer_sizes': (50,)}
# mean: 0.77951, std: 0.04568, params: {'learning_rate_init': 0.075, 'hidden_layer_sizes': (50,)}
# mean: 0.78125, std: 0.04872, params: {'learning_rate_init': 0.1, 'hidden_layer_sizes': (50,)}
# mean: 0.78125, std: 0.03147, params: {'learning_rate_init': 0.125, 'hidden_layer_sizes': (50,)}
# mean: 0.77778, std: 0.04518, params: {'learning_rate_init': 0.15, 'hidden_layer_sizes': (50,)}
# mean: 0.77083, std: 0.04657, params: {'learning_rate_init': 0.05, 'hidden_layer_sizes': (75,)}
# mean: 0.77431, std: 0.04601, params: {'learning_rate_init': 0.075, 'hidden_layer_sizes': (75,)}
# mean: 0.78299, std: 0.04189, params: {'learning_rate_init': 0.1, 'hidden_layer_sizes': (75,)}
# mean: 0.78299, std: 0.04545, params: {'learning_rate_init': 0.125, 'hidden_layer_sizes': (75,)}
# mean: 0.77431, std: 0.04052, params: {'learning_rate_init': 0.15, 'hidden_layer_sizes': (75,)}
# mean: 0.78125, std: 0.03879, params: {'learning_rate_init': 0.05, 'hidden_layer_sizes': (100,)}
# mean: 0.77431, std: 0.05091, params: {'learning_rate_init': 0.075, 'hidden_layer_sizes': (100,)}
# mean: 0.78299, std: 0.04153, params: {'learning_rate_init': 0.1, 'hidden_layer_sizes': (100,)}
# mean: 0.77604, std: 0.04532, params: {'learning_rate_init': 0.125, 'hidden_layer_sizes': (100,)}
# mean: 0.78472, std: 0.04961, params: {'learning_rate_init': 0.15, 'hidden_layer_sizes': (100,)}
# mean: 0.78299, std: 0.04602, params: {'learning_rate_init': 0.05, 'hidden_layer_sizes': 125}
# mean: 0.77778, std: 0.03499, params: {'learning_rate_init': 0.075, 'hidden_layer_sizes': 125}
# mean: 0.77951, std: 0.04434, params: {'learning_rate_init': 0.1, 'hidden_layer_sizes': 125}
# mean: 0.78299, std: 0.04116, params: {'learning_rate_init': 0.125, 'hidden_layer_sizes': 125}
# mean: 0.77778, std: 0.03670, params: {'learning_rate_init': 0.15, 'hidden_layer_sizes': 125}
# Training error: 0.210069444444
# Testing error: 0.25
# ##############################################################

# %% [markdown]
# ## Feedforward ANN con weight decay

# %%
#parameters to try on MPL
mlp_params = {'alpha':[0.0001, 0.0005, 0.001, 0.005, 0.01, 0.05, 0.1, 0.5]}

# %%
mlp = MLPClassifier(activation='logistic', algorithm='sgd', learning_rate='constant', learning_rate_init=0.075, hidden_layer_sizes=(75,))
mlp_tr_err, mlp_ts_err = solve_clf(mlp, params=mlp_params, show=range(20))
# Out:
# ##############################################################
# Dataset: 0
# Best parameter: {'alpha': 0.05}
# CV scores:
# mean: 0.75521, std: 0.03574, params: {'alpha': 0.0001}
# mean: 0.76910, std: 0.03986, params: {'alpha': 0.0005}
# mean: 0.76215, std: 0.04492, params: {'alpha': 0.001}
# mean: 0.76215, std: 0.03749, params: {'alpha': 0.005}
# mean: 0.76736, std: 0.03664, params: {'alpha': 0.01}
# mean: 0.77257, std: 0.03229, params: {'alpha': 0.05}
# mean: 0.76736, std: 0.03695, params: {'alpha': 0.1}
# mean: 0.76910, std: 0.03690, params: {'alpha': 0.5}
# Training error: 0.215277777778
# Testing error: 0.25
# ##############################################################
#
#
# ##############################################################
# Dataset: 1
# Best parameter: {'alpha': 0.5}
# CV scores:
# mean: 0.75347, std: 0.03709, params: {'alpha': 0.0001}
# mean: 0.76042, std: 0.02872, params: {'alpha': 0.0005}
# mean: 0.75174, std: 0.02779, params: {'alpha': 0.001}
# mean: 0.75694, std: 0.04144, params: {'alpha': 0.005}
# mean: 0.75000, std: 0.02527, params: {'alpha': 0.01}
# mean: 0.75521, std: 0.01980, params: {'alpha': 0.05}
# mean: 0.75868, std: 0.03612, params: {'alpha': 0.1}
# mean: 0.76215, std: 0.03657, params: {'alpha': 0.5}
# Training error: 0.229166666667
# Testing error: 0.197916666667
# ##############################################################
#
#
# ##############################################################
# Dataset: 2
# Best parameter: {'alpha': 0.05}
# CV scores:
# mean: 0.78299, std: 0.03271, params: {'alpha': 0.0001}
# mean: 0.78472, std: 0.02850, params: {'alpha': 0.0005}
# mean: 0.78299, std: 0.03031, params: {'alpha': 0.001}
# mean: 0.78646, std: 0.02453, params: {'alpha': 0.005}
# mean: 0.78819, std: 0.03152, params: {'alpha': 0.01}
# mean: 0.78993, std: 0.02726, params: {'alpha': 0.05}
# mean: 0.77951, std: 0.02556, params: {'alpha': 0.1}
# mean: 0.78472, std: 0.02067, params: {'alpha': 0.5}
# Training error: 0.211805555556
# Testing error: 0.270833333333
# ##############################################################
#
#
# ##############################################################
# Dataset: 3
# Best parameter: {'alpha': 0.005}
# CV scores:
# mean: 0.77257, std: 0.02805, params: {'alpha': 0.0001}
# mean: 0.77083, std: 0.02243, params: {'alpha': 0.0005}
# mean: 0.77431, std: 0.02089, params: {'alpha': 0.001}
# mean: 0.77778, std: 0.01778, params: {'alpha': 0.005}
# mean: 0.76736, std: 0.02399, params: {'alpha': 0.01}
# mean: 0.77604, std: 0.03027, params: {'alpha': 0.05}
# mean: 0.76910, std: 0.02193, params: {'alpha': 0.1}
# mean: 0.77431, std: 0.01696, params: {'alpha': 0.5}
# Training error: 0.215277777778
# Testing error: 0.21875
# ##############################################################
#
#
# ##############################################################
# Dataset: 4
# Best parameter: {'alpha': 0.0001}
# CV scores:
# mean: 0.76910, std: 0.01530, params: {'alpha': 0.0001}
# mean: 0.75868, std: 0.02169, params: {'alpha': 0.0005}
# mean: 0.76562, std: 0.02401, params: {'alpha': 0.001}
# mean: 0.76215, std: 0
params: {'alpha': 0.5}
# Training error: 0.215277777778
# Testing error: 0.21875
# ##############################################################
#
#
# ##############################################################
# Dataset: 19
# Best parameter: {'alpha': 0.1}
# CV scores:
# mean: 0.75347, std: 0.01978, params: {'alpha': 0.0001}
# mean: 0.75521, std: 0.03205, params: {'alpha': 0.0005}
# mean: 0.75521, std: 0.02732, params: {'alpha': 0.001}
# mean: 0.75521, std: 0.02483, params: {'alpha': 0.005}
# mean: 0.75694, std: 0.02329, params: {'alpha': 0.01}
# mean: 0.74653, std: 0.02635, params: {'alpha': 0.05}
# mean: 0.76042, std: 0.02910, params: {'alpha': 0.1}
# mean: 0.75694, std: 0.02816, params: {'alpha': 0.5}
# Training error: 0.227430555556
# Testing error: 0.203125
# ##############################################################
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-80-125abf9889d0> in <module>()
#       1 mlp = MLPClassifier(activation='logistic', algorithm='sgd', learning_rate='constant', learning_rate_init=0.075, hidden_layer_sizes=(75,))
# ----> 2 mlp_tr_err, mlp_ts_err = solve_clf(mlp, params=mlp_params, show=range(20))
#
# <ipython-input-78-e771deb46051> in solve_clf(clf, params, scale, show)
#     120     if show:
#     121         plot_error(tr_err, ts_err)
# --> 122         if params is not None: make_hist(winners, params)
#     123     return (tr_err,ts_err)
#
# <ipython-input-78-e771deb46051> in make_hist(winners, params)
#      21         plt.ylabel('Frequency')
#      22         plt.title('Histogram of {0}'.format(key))
# ---> 23         plt.bar(pos, freqs, width, color='0.5')
#      24         plt.show()
#      25
#
# /home/martin/anaconda2/envs/scikit18/lib/python2.7/site-packages/matplotlib/pyplot.py in bar(left, height, width, bottom, hold, data, **kwargs)
#    2641     try:
#    2642         ret = ax.bar(left, height, width=width, bottom=bottom, data=data,
# -> 2643                      **kwargs)
#    2644     finally:
#    2645         ax.hold(washold)
#
# /home/martin/anaconda2/envs/scikit18/lib/python2.7/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1810                     warnings.warn(msg % (label_namer, func.__name__),
#    1811                                   RuntimeWarning, stacklevel=2)
# -> 1812             return func(ax, *args, **kwargs)
#    1813         pre_doc = inner.__doc__
#    1814         if pre_doc is None:
#
# /home/martin/anaconda2/envs/scikit18/lib/python2.7/site-packages/matplotlib/axes/_axes.py in bar(self, left, height, width, bottom, **kwargs)
#    2078         if len(height) != nbars:
#    2079             raise ValueError("incompatible sizes: argument 'height' "
# -> 2080                               "must be length %d or scalar" % nbars)
#    2081         if len(width) != nbars:
#    2082             raise ValueError("incompatible sizes: argument 'width' "
#
# ValueError: incompatible sizes: argument 'height' must be length 8 or scalar

# %% [markdown]
# ## Extreme Learning Machine

# %%
elm_params = {'n_hidden':[50,100,150,200,250]}

# %%
elm = ELM()
elm_tr_err, elm_ts_err = solve_clf(elm, params=elm_params, show=range(20))
# Out:
# ##############################################################
# Dataset: 0
# Best parameter: {'n_hidden': 150}
# CV scores:
# mean: 0.76389, std: 0.03206, params: {'n_hidden': 50}
# mean: 0.76910, std: 0.04199, params: {'n_hidden': 100}
# mean: 0.77431, std: 0.03512, params: {'n_hidden': 150}
# mean: 0.77083, std: 0.03898, params: {'n_hidden': 200}
# mean: 0.76910, std: 0.03967, params: {'n_hidden': 250}
# Training error: 0.208333333333
# Testing error: 0.260416666667
# ##############################################################
#
#
# ##############################################################
# Dataset: 1
# Best parameter: {'n_hidden': 100}
# CV scores:
# mean: 0.74826, std: 0.03148, params: {'n_hidden': 50}
# mean: 0.76042, std: 0.04014, params: {'n_hidden': 100}
# mean: 0.75521, std: 0.04087, params: {'n_hidden': 150}
# mean: 0.75694, std: 0.03880, params: {'n_hidden': 200}
# mean: 0.75521, std: 0.04087, params: {'n_hidden': 250}
# Training error: 0.230902777778
# Testing error: 0.203125
# ##############################################################
#
#
# ##############################################################
# Dataset: 2
# Best parameter: {'n_hidden': 150}
# CV scores:
# mean: 0.78993, std: 0.02075, params: {'n_hidden': 50}
# mean: 0.78646, std: 0.02737, params: {'n_hidden': 100}
# mean: 0.79167, std: 0.03007, params: {'n_hidden': 150}
# mean: 0.78819, std: 0.02834, params: {'n_hidden': 200}
# mean: 0.78819, std: 0.02971, params: {'n_hidden': 250}
# Training error: 0.203125
# Testing error: 0.260416666667
# ##############################################################
#
#
# ##############################################################
# Dataset: 3
# Best parameter: {'n_hidden': 50}
# CV scores:
# mean: 0
# Testing error: 0.197916666667
# ##############################################################
#
#
# ##############################################################
# Dataset: 19
# Best parameter: {'n_hidden': 100}
# CV scores:
# mean: 0.75347, std: 0.02437, params: {'n_hidden': 50}
# mean: 0.75521, std: 0.02501, params: {'n_hidden': 100}
# mean: 0.75521, std: 0.03081, params: {'n_hidden': 150}
# mean: 0.75347, std: 0.02455, params: {'n_hidden': 200}
# mean: 0.75347, std: 0.02473, params: {'n_hidden': 250}
# Training error: 0.230902777778
# Testing error: 0.197916666667
# ##############################################################

# %% [markdown]
# ## AdaBoost

# %%
clf = AdaBoost(base_estimator=DecisionTree(max_depth=3), n_estimators=20)
adaboost_tr_err, adaboost_ts_err = solve_clf(clf, scale=False, show=range(20))
# Out:
# ##############################################################
# Dataset: 0
# Training error: 0.00868055555556
# Testing error: 0.291666666667
# ##############################################################
#
#
# ##############################################################
# Dataset: 1
# Training error: 0.0295138888889
# Testing error: 0.286458333333
# ##############################################################
#
#
# ##############################################################
# Dataset: 2
# Training error: 0.0138888888889
# Testing error: 0.322916666667
# ##############################################################
#
#
# ##############################################################
# Dataset: 3
# Training error: 0.0277777777778
# Testing error: 0.270833333333
# ##############################################################
#
#
# ##############################################################
# Dataset: 4
# Training error: 0.0208333333333
# Testing error: 0.338541666667
# ##############################################################
#
#
# ##############################################################
# Dataset: 5
# Training error: 0.00868055555556
# Testing error: 0.307291666667
# ##############################################################
#
#
# ##############################################################
# Dataset: 6
# Training error: 0.0260416666667
# Testing error: 0.333333333333
# ##############################################################
#
#
# ##############################################################
# Dataset: 7
# Training error: 0.015625
# Testing error: 0.328125
# ##############################################################
#
#
# ##############################################################
# Dataset: 8
# Training error: 0.00347222222222
# Testing error: 0.328125
# ##############################################################
#
#
# ##############################################################
# Dataset: 9
# Training error: 0.0243055555556
# Testing error: 0.328125
# ##############################################################
#
#
# ##############################################################
# Dataset: 10
# Training error: 0.015625
# Testing error: 0.302083333333
# ##############################################################
#
#
# ##############################################################
# Dataset: 11
# Training error: 0.0173611111111
# Testing error: 0.302083333333
# ##############################################################
#
#
# ##############################################################
# Dataset: 12
# Training error: 0.015625
# Testing error: 0.286458333333
# ##############################################################
#
#
# ##############################################################
# Dataset: 13
# Training error: 0.0208333333333
# Testing error: 0.276041666667
# ##############################################################
#
#
# ##############################################################
# Dataset: 14
# Training error: 0.0190972222222
# Testing error: 0.354166666667
# ##############################################################
#
#
# ##############################################################
# Dataset: 15
# Training error: 0.0121527777778
# Testing error: 0.317708333333
# ##############################################################
#
#
# ##############################################################
# Dataset: 16
# Training error: 0.015625
# Testing error: 0.265625
# ##############################################################
#
#
# ##############################################################
# Dataset: 17
# Training error: 0.00173611111111
# Testing error: 0.286458333333
# ##############################################################
#
#
# ##############################################################
# Dataset: 18
# Training error: 0.0190972222222
# Testing error: 0.307291666667
# ##############################################################
#
#
# ##############################################################
# Dataset: 19
# Training error: 0.0208333333333
# Testing error: 0.255208333333
# ##############################################################

# %% [markdown]
# ## Bagging

# %%
clf = Bagging(n_estimators=20, max_depth=3)
bagging_tr_err, bagging_ts_err = solve_clf(clf, scale=False, show=range(20))
# Out:
# ##############################################################
# Dataset: 0
# Training error: 0.197916666667
# Testing error: 0.260416666667
# ##############################################################
#
#
# ##############################################################
# Dataset: 1
# Training error: 0.204861111111
# Testing error: 0.203125
# ##############################################################
#
#
# ##############################################################
# Dataset: 2
# Training error: 0.192708333333
# Testing error: 0.296875
# ##############################################################
#
#
# ##############################################################
# Dataset: 3
# Training error: 0.190972222222
# Testing error: 0.229166666667
# ##############################################################
#
#
# ##############################################################
# Dataset: 4
# Training error: 0.215277777778
# Testing error: 0.208333333333
# ##############################################################
#
#
# ##############################################################
# Dataset: 5
# Training error: 0.197916666667
# Testing error: 0.25
# ##############################################################
#
#
# ##############################################################
# Dataset: 6
# Training error: 0.203125
# Testing error: 0.270833333333
# ##############################################################
#
#
# ##############################################################
# Dataset: 7
# Training error: 0.206597222222
# Testing error: 0.244791666667
# ##############################################################
#
#
# ##############################################################
# Dataset: 8
# Training error: 0.203125
# Testing error: 0.260416666667
# ##############################################################
#
#
# ##############################################################
# Dataset: 9
# Training error: 0.204861111111
# Testing error: 0.265625
# ##############################################################
#
#
# ##############################################################
# Dataset: 10
# Training error: 0.199652777778
# Testing error: 0.229166666667
# ##############################################################
#
#
# ##############################################################
# Dataset: 11
# Training error: 0.204861111111
# Testing error: 0.276041666667
# ##############################################################
#
#
# ##############################################################
# Dataset: 12
# Training error: 0.194444444444
# Testing error: 0.260416666667
# ##############################################################
#
#
# ##############################################################
# Dataset: 13
# Training error: 0.206597222222
# Testing error: 0.234375
# ##############################################################
#
#
# ##############################################################
# Dataset: 14
# Training error: 0.203125
# Testing error: 0.276041666667
# ##############################################################
#
#
# ##############################################################
# Dataset: 15
# Training error: 0.178819444444
# Testing error: 0.25
# ##############################################################
#
#
# ##############################################################
# Dataset: 16
# Training error: 0.192708333333
# Testing error: 0.239583333333
# ##############################################################
#
#
# ##############################################################
# Dataset: 17
# Training error: 0.189236111111
# Testing error: 0.3125
# ##############################################################
#
#
# ##############################################################
# Dataset: 18
# Training error: 0.204861111111
# Testing error: 0.229166666667
# ##############################################################
#
#
# ##############################################################
# Dataset: 19
# Training error: 0.220486111111
# Testing error: 0.28125
# ##############################################################

# %% [markdown]
# ## Comparaciones

# %%
errors = {'ELM':elm_ts_err, 'AdaBoost':adaboost_ts_err, 'Bagging':bagging_ts_err}

# %%
plot_errorbars(errors)

# %% [markdown]
# ## Anexo de Código

# %% [markdown]
# **Observación:** Para la correcta ejecución del código en el informe, primero se deben ejecutar las celdas del anexo de código aquí abajo.

# %% [markdown]
# ### Configuración del notebook

# %%
#notebook settings
# %matplotlib inline

#import some useful libraries and utilities
import numpy as np
import scipy as sp
import matplotlib.cm as cm
import matplotlib.pyplot as plt
from sklearn.grid_search import GridSearchCV
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.utils import resample
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier as DecisionTree
from sklearn.ensemble import AdaBoostClassifier as AdaBoost

# %% [markdown]
# ### Configuración del notebook

# %% [markdown]
# ## Métricas de error para clasificación

# %%
#precision
def precision(yreal, ypred):
    yr = yreal.astype(int)
    yp = ypred.astype(int) 
    m, = yr.shape
    #number of good predictions/number of predictions
    return np.sum(yp==yr)/float(m)

#error rate 
def error_rate(yreal, ypred):
    return 1.-precision(yreal, ypred)

# %% [markdown]
# ## Funciones complementarias (helpers) para obtener resultados

# %%
"""
Function to generate histogram of winners
"""
def make_hist(winners,params):
    for key in winners:
        par = params[key]
        win = np.array(winners[key])
        freqs = np.zeros(5)
        for i in xrange(5):
            freqs[i] = np.sum(par[i]==win)
        labels = map(str,par)
        pos = np.arange(len(labels))
        width = 1.0
        fig = plt.figure()
        fig.set_figheight(9)
        fig.set_figwidth(9)
        ax = plt.axes()
        ax.set_xticks(pos + (width / 2))
        ax.set_xticklabels(labels)
        plt.xlabel('Parameters')
        plt.ylabel('Frequency')
        plt.title('Histogram of {0}'.format(key))
        plt.bar(pos, freqs, width, color='0.5')
        plt.show()
    
def plot_error(tr_err, ts_err):
    x = np.arange(20)
    plt.figure(figsize=(12,6))
    plt.plot(x, tr_err, marker='o', linestyle='--', color='b', label='Training Error')
    plt.plot(x, ts_err, marker='o', linestyle='--', color='r', label='Testing Error')
    plt.xlabel('Datasets')
    plt.ylabel('Error Rate')
    plt.title('Training and testing error rates in each dataset')
    plt.legend(bbox_to_anchor=(1.25, 1.0))
    plt.show()
    

def mean_confidence_interval(data, confidence=0.9):
    #computing confidence interval
    n = data.shape[0]
    mu = np.mean(data)
    sem = sp.stats.sem(data)
    h1,h2 = sp.stats.t.interval(confidence, n-1, loc=mu, scale=sem)
    return mu, h1, h2

def mean_percentile(data, inf=10, sup=90):
    mu = np.mean(data)
    h1, h2 = np.percentile(data, [10,90])
    return mu, h1, h2

def plot_errorbars(errors):
    mean = []
    lower = []
    upper = []
    labels = []
    for label,error in errors.iteritems():
        mu,l,u = mean_confidence_interval(error)
        #mu,l,u = mean_percentile(error)
        mean.append(mu)
        lower.append(l)
        upper.append(u)
        labels.append(label)
    x = np.arange(3, len(errors)+3)
    mean = np.array(mean)
    lower = mean-np.array(lower)
    upper = np.array(upper)-mean
    plt.figure(figsize=(12,6))
    plt.xlim([2,len(errors)+3])
    plt.xticks(x, labels)
    plt.errorbar(x, mean, yerr=[lower,upper],fmt='o')
    plt.xlabel('Algorithm')
    plt.ylabel('Mean error rate')
    plt.title('Error bars with different algorithms')
    plt.show()

"""
Generate solutions for classification problems
"""
def solve_clf(clf, params=None, scale=True, show=None):
    if params is not None:
        winners = dict()
        for key in params:
            winners[key] = list()
            
    #set dataset name
    path = './diabetes/diabetes'
    
    #error-rates to plot
    tr_err = np.empty(20)
    ts_err = np.empty(20)
    
    #iterate through data
    for i in xrange(20):
        #loading datasets
        tr_file = path+'-tr-{0}.npy'.format(i)
        ts_file = path+'-ts-{0}.npy'.format(i)
            
        tr_data = np.load(tr_file)
        ts_data = np.load(ts_file)
        
        if scale:
            #perform same scaling on training and testing sets
            scaler = StandardScaler()
            scaler.fit(tr_data[:,:-1])
            X_tr = scaler.transform(tr_data[:,:-1])
            X_ts = scaler.transform(ts_data[:,:-1])
        else: 
            X_tr = tr_data[:,:-1]
            X_ts = ts_data[:,:-1]
        y_tr = np.ascontiguousarray(tr_data[:,-1])
        y_ts = np.ascontiguousarray(ts_data[:,-1])

        if params is not None:
            #tunning parameters
            gs = GridSearchCV(clf, params, cv=5, n_jobs=2)
            gs.fit(X_tr, y_tr)
            grid_scores = gs.grid_scores_
            best_params = gs.best_params_
            for key in winners:
                bparam = best_params[key]
                if type(bparam)==tuple:
                    winners[key].append(bparam[0])
                else:
                    winners[key].append(bparam)
            #traininig with best parameters
            clf.set_params(**best_params)
            clf.fit(X_tr, y_tr)
        else:
            clf.fit(X_tr, y_tr)
        
        #computing errors
        tr_err[i] = error_rate(y_tr, clf.predict(X_tr))
        ts_err[i] = error_rate(y_ts, clf.predict(X_ts))
        
        if (show is not None) and (i not in show): continue
        print "##############################################################"
        print "Dataset: {0}".format(i)
        if params is not None:
            print 'Best parameter: {0}'.format(best_params)
            print 'CV scores:'
            for result in grid_scores: print result
        print 'Training error: {0}'.format(tr_err[i])
        print 'Testing error: {0}'.format(ts_err[i])
        print "##############################################################"
        print '\n'
    
    #ploting errors
    if show: 
        plot_error(tr_err, ts_err)
        if params is not None: make_hist(winners, params)
    return (tr_err,ts_err)

# %% [markdown]
# ## Implementación de Extreme Learning Machine

# %%
def sigmoid(z):
    return 1./(1.+np.exp(-z))

# %%
class ELM(BaseEstimator, ClassifierMixin):
    def __init__(self, n_hidden=10, activation=sigmoid):
        self.n_hidden = n_hidden
        self.activation = activation
    
    def fit(self, X, y):
        #creating a random matrix W with the weights of the hidden layer
        #weights are between -0.5 and 0.5
        M,I = X.shape
        W = np.random.random((I,self.n_hidden))
        W -= 0.5
        #storing it in the object attribute
        self.W = W
        
        #computing output values of hidden nodes
        H = self.activation(np.dot(X,W))
        
        #softmax-logistic regression
        clf = LogisticRegression()
        clf.fit(H,y)
        self.clf = clf
        return self
    
    def predict(self, X):
        H = self.activation(np.dot(X,self.W))
        return self.clf.predict(H)
    
    def score(self, X, y):
        H = self.activation(np.dot(X,self.W))
        return self.clf.score(H,y)

# %% [markdown]
# ## Implementación de Bagging

# %%
class Bagging(BaseEstimator,ClassifierMixin):
    def __init__(self, n_estimators=5, max_depth=1):
        self.n_estimators = n_estimators
        self.max_depth = max_depth
        
    def fit(self, X, y):
        #list where estimators will be stored
        estimators = []
        #indexes of X
        ind = np.arange(X.shape[0])
        #fitting all the classifiers
        for i in xrange(self.n_estimators):
            #bootstraped indexes
            b_ind = resample(ind, replace=True)
            clf = DecisionTree(max_depth=self.max_depth)
            clf.fit(X[b_ind], y[b_ind])
            estimators.append(clf)
        #storing results
        self.estimators = estimators
        return self
    
    def predict(self, X):
        #array with probabilies of classes
        prob = np.zeros((X.shape[0],2))
        for clf in self.estimators:
            prob += clf.predict_proba(X)
        #taking average probability
        prob /= self.n_estimators
        return np.argmax(prob, axis=1)
    
    def score(self, X, y):
        ypred = self.predict(X)
        return precision(y, ypred)

# %%
a = np.random.random(100)

# %%
np.percentile(a, [20,80])
# Out:
# array([ 0.22095925,  0.82624562])
